# %% [markdown]
# # INTRODUCTION
#
# ### Task Details
# An organization wants to predict who possible defaulters are for the consumer loans product. They have data about historic customer behavior based on what they have observed. Hence when they acquire new customers they want to predict who is riskier and who is not.
#
# ### What do you have to do?
# You are required to use the training dataset to identify patterns that predict “potential” defaulters.
#
# ### Expected Submission
# Submissions should be made in the same format as the Sample Notebook provided. Train/Test split should be 80% for training & 20% for testing.
#
# ### Evaluation
# Submissions will be evaluated on the basis of roc_auc_score on 20% of train_dataset.
#
# <img src="https://www.onlygfx.com/wp-content/uploads/2020/05/alert-stamp-3.png" width="600" height="200" />

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/loan-prediction-based-on-customer-behavior/Test Data.csv
# /kaggle/input/loan-prediction-based-on-customer-behavior/Training Data.csv
# /kaggle/input/loan-prediction-based-on-customer-behavior/Sample Prediction Dataset.csv

# %% [markdown]
# #### Import libraries and set options

# %%
import seaborn as sns
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 20)
sns.set_theme(color_codes=True, style='darkgrid', 
              palette='deep', font='sans-serif')

# %% [markdown]
# # IMPORT DATA AND DATA CLEANSING

# %%
df_train = pd.read_csv ( '/kaggle/input/loan-prediction-based-on-customer-behavior/Training Data.csv' )
df_train.drop ('Id', axis = 1, inplace = True )
df_train.head().style.set_properties(**{'background-color':'black',
                                     'color': 'white'})
# Out:
# <style  type="text/css" >
# #T_0599c_row0_col0,#T_0599c_row0_col1,#T_0599c_row0_col2,#T_0599c_row0_col3,#T_0599c_row0_col4,#T_0599c_row0_col5,#T_0599c_row0_col6,#T_0599c_row0_col7,#T_0599c_row0_col8,#T_0599c_row0_col9,#T_0599c_row0_col10,#T_0599c_row0_col11,#T_0599c_row1_col0,#T_0599c_row1_col1,#T_0599c_row1_col2,#T_0599c_row1_col3,#T_0599c_row1_col4,#T_0599c_row1_col5,#T_0599c_row1_col6,#T_0599c_row1_col7,#T_0599c_row1_col8,#T_0599c_row1_col9,#T_0599c_row1_col10,#T_0599c_row1_col11,#T_0599c_row2_col0,#T_0599c_row2_col1,#T_0599c_row2_col2,#T_0599c_row2_col3,#T_0599c_row2_col4,#T_0599c_row2_col5,#T_0599c_row2_col6,#T_0599c_row2_col7,#T_0599c_row2_col8,#T_0599c_row2_col9,#T_0599c_row2_col10,#T_0599c_row2_col11,#T_0599c_row3_col0,#T_0599c_row3_col1,#T_0599c_row3_col2,#T_0599c_row3_col3,#T_0599c_row3_col4,#T_0599c_row3_col5,#T_0599c_row3_col6,#T_0599c_row3_col7,#T_0599c_row3_col8,#T_0599c_row3_col9,#T_0599c_row3_col10,#T_0599c_row3_col11,#T_0599c_row4_col0,#T_0599c_row4_col1,#T_0599c_row4_col2,#T_0599c_row4_col3,#T_0599c_row4_col4,#T_0599c_row4_col5,#T_0599c_row4_col6,#T_0599c_row4_col7,#T_0599c_row4_col8,#T_0599c_row4_col9,#T_0599c_row4_col10,#T_0599c_row4_col11{
#             background-color:  black;
#             color:  white;
#         }</style><table id="T_0599c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Income</th>        <th class="col_heading level0 col1" >Age</th>        <th class="col_heading level0 col2" >Experience</th>        <th class="col_heading level0 col3" >Married/Single</th>        <th class="col_heading level0 col4" >House_Ownership</th>        <th class="col_heading level0 col5" >Car_Ownership</th>        <th class="col_heading level0 col6" >Profession</th>        <th class="col_heading level0 col7" >CITY</th>        <th class="col_heading level0 col8" >STATE</th>        <th class="col_heading level0 col9" >CURRENT_JOB_YRS</th>        <th class="col_heading level0 col10" >CURRENT_HOUSE_YRS</th>        <th class="col_heading level0 col11" >Risk_Flag</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0599c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0599c_row0_col0" class="data row0 col0" >1303834</td>
#                         <td id="T_0599c_row0_col1" class="data row0 col1" >23</td>
#                         <td id="T_0599c_row0_col2" class="data row0 col2" >3</td>
#                         <td id="T_0599c_row0_col3" class="data row0 col3" >single</td>
#                         <td id="T_0599c_row0_col4" class="data row0 col4" >rented</td>
#                         <td id="T_0599c_row0_col5" class="data row0 col5" >no</td>
#                         <td id="T_0599c_row0_col6" class="data row0 col6" >Mechanical_engineer</td>
#                         <td id="T_0599c_row0_col7" class="data row0 col7" >Rewa</td>
#                         <td id="T_0599c_row0_col8" class="data row0 col8" >Madhya_Pradesh</td>
#                         <td id="T_0599c_row0_col9" class="data row0 col9" >3</td>
#                         <td id="T_0599c_row0_col10" class="data row0 col10" >13</td>
#                         <td id="T_0599c_row0_col11" class="data row0 col11" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_0599c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0599c_row1_col0" class="data row1 col0" >7574516</td>
#                         <td id="T_0599c_row1_col1" class="data row1 col1" >40</td>
#                         <td id="T_0599c_row1_col2" class="data row1 col2" >10</td>
#                         <td id="T_0599c_row1_col3" class="data row1 col3" >single</td>
#                         <td id="T_0599c_row1_col4" class="data row1 col4" >rented</td>
#                         <td id="T_0599c_row1_col5" class="data row1 col5" >no</td>
#                         <td id="T_0599c_row1_col6" class="data row1 col6" >Software_Developer</td>
#                         <td id="T_0599c_row1_col7" class="data row1 col7" >Parbhani</td>
#                         <td id="T_0599c_row1_col8" class="data row1 col8" >Maharashtra</td>
#                         <td id="T_0599c_row1_col9" class="data row1 col9" >9</td>
#                         <td id="T_0599c_row1_col10" class="data row1 col10" >13</td>
#                         <td id="T_0599c_row1_col11" class="data row1 col11" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_0599c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0599c_row2_col0" class="data row2 col0" >3991815</td>
#                         <td id="T_0599c_row2_col1" class="data row2 col1" >66</td>
#                         <td id="T_0599c_row2_col2" class="data row2 col2" >4</td>
#                         <td id="T_0599c_row2_col3" class="data row2 col3" >married</td>
#                         <td id="T_0599c_row2_col4" class="data row2 col4" >rented</td>
#                         <td id="T_0599c_row2_col5" class="data row2 col5" >no</td>
#                         <td id="T_0599c_row2_col6" class="data row2 col6" >Technical_writer</td>
#                         <td id="T_0599c_row2_col7" class="data row2 col7" >Alappuzha</td>
#                         <td id="T_0599c_row2_col8" class="data row2 col8" >Kerala</td>
#                         <td id="T_0599c_row2_col9" class="data row2 col9" >4</td>
#                         <td id="T_0599c_row2_col10" class="data row2 col10" >10</td>
#                         <td id="T_0599c_row2_col11" class="data row2 col11" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_0599c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0599c_row3_col0" class="data row3 col0" >6256451</td>
#                         <td id="T_0599c_row3_col1" class="data row3 col1" >41</td>
#                         <td id="T_0599c_row3_col2" class="data row3 col2" >2</td>
#                         <td id="T_0599c_row3_col3" class="data row3 col3" >single</td>
#                         <td id="T_0599c_row3_col4" class="data row3 col4" >rented</td>
#                         <td id="T_0599c_row3_col5" class="data row3 col5" >yes</td>
#                         <td id="T_0599c_row3_col6" class="data row3 col6" >Software_Developer</td>
#                         <td id="T_0599c_row3_col7" class="data row3 col7" >Bhubaneswar</td>
#                         <td id="T_0599c_row3_col8" class="data row3 col8" >Odisha</td>
#                         <td id="T_0599c_row3_col9" class="data row3 col9" >2</td>
#                         <td id="T_0599c_row3_col10" class="data row3 col10" >12</td>
#                         <td id="T_0599c_row3_col11" class="data row3 col11" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_0599c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0599c_row4_col0" class="data row4 col0" >5768871</td>
#                         <td id="T_0599c_row4_col1" class="data row4 col1" >47</td>
#                         <td id="T_0599c_row4_col2" class="data row4 col2" >11</td>
#                         <td id="T_0599c_row4_col3" class="data row4 col3" >single</td>
#                         <td id="T_0599c_row4_col4" class="data row4 col4" >rented</td>
#                         <td id="T_0599c_row4_col5" class="data row4 col5" >no</td>
#                         <td id="T_0599c_row4_col6" class="data row4 col6" >Civil_servant</td>
#                         <td id="T_0599c_row4_col7" class="data row4 col7" >Tiruchirappalli[10]</td>
#                         <td id="T_0599c_row4_col8" class="data row4 col8" >Tamil_Nadu</td>
#                         <td id="T_0599c_row4_col9" class="data row4 col9" >3</td>
#                         <td id="T_0599c_row4_col10" class="data row4 col10" >14</td>
#                         <td id="T_0599c_row4_col11" class="data row4 col11" >1</td>
#             </tr>
#     </tbody></table>

# %%
df_train.isnull().sum()
# Out:
# Income               0
# Age                  0
# Experience           0
# Married/Single       0
# House_Ownership      0
# Car_Ownership        0
# Profession           0
# CITY                 0
# STATE                0
# CURRENT_JOB_YRS      0
# CURRENT_HOUSE_YRS    0
# Risk_Flag            0
# dtype: int64

# %% [markdown]
# ###### There are no missing-values ​​in the training dataset.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Income             252000 non-null  int64
#  1   Age                252000 non-null  int64
#  2   Experience         252000 non-null  int64
#  3   Married/Single     252000 non-null  object
#  4   House_Ownership    252000 non-null  object
#  5   Car_Ownership      252000 non-null  object
#  6   Profession         252000 non-null  object
#  7   CITY               252000 non-null  object
#  8   STATE              252000 non-null  object
#  9   CURRENT_JOB_YRS    252000 non-null  int64
#  10  CURRENT_HOUSE_YRS  252000 non-null  int64
#  11  Risk_Flag          252000 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 23.1+ MB

# %%
# set target variable as category
df_train['Risk_Flag']=df_train['Risk_Flag'].astype('category')

# %% [markdown]
# # EDA

# %%
#Import ploting libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots 
colors = ['#ffa07a','#00b2ff']
sns.set(palette=colors, font='Serif', style='white', rc={'axes.facecolor':'#f1f1f1', 'figure.facecolor':'#f1f1f1'})
sns.palplot(colors)

# %%
df_train.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='tab10')
# Out:
# <style  type="text/css" >
# #T_73fcf_row0_col0,#T_73fcf_row1_col0,#T_73fcf_row1_col1,#T_73fcf_row1_col2,#T_73fcf_row1_col5,#T_73fcf_row2_col0,#T_73fcf_row2_col1,#T_73fcf_row2_col2,#T_73fcf_row2_col5,#T_73fcf_row3_col0,#T_73fcf_row3_col1,#T_73fcf_row3_col2,#T_73fcf_row3_col5,#T_73fcf_row4_col0,#T_73fcf_row4_col1,#T_73fcf_row4_col2,#T_73fcf_row4_col5{
#             background-color:  #1f77b4;
#             color:  #000000;
#         }#T_73fcf_row0_col1,#T_73fcf_row0_col2,#T_73fcf_row0_col5{
#             background-color:  #17becf;
#             color:  #000000;
#         }</style><table id="T_73fcf_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73fcf_level0_row0" class="row_heading level0 row0" >Income</th>
#                         <td id="T_73fcf_row0_col0" class="data row0 col0" >252000.000000</td>
#                         <td id="T_73fcf_row0_col1" class="data row0 col1" >4997116.665325</td>
#                         <td id="T_73fcf_row0_col2" class="data row0 col2" >2878311.013611</td>
#                         <td id="T_73fcf_row0_col3" class="data row0 col3" >10310.000000</td>
#                         <td id="T_73fcf_row0_col4" class="data row0 col4" >2503015.000000</td>
#                         <td id="T_73fcf_row0_col5" class="data row0 col5" >5000694.500000</td>
#                         <td id="T_73fcf_row0_col6" class="data row0 col6" >7477502.000000</td>
#                         <td id="T_73fcf_row0_col7" class="data row0 col7" >9999938.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_73fcf_level0_row1" class="row_heading level0 row1" >Age</th>
#                         <td id="T_73fcf_row1_col0" class="data row1 col0" >252000.000000</td>
#                         <td id="T_73fcf_row1_col1" class="data row1 col1" >49.954071</td>
#                         <td id="T_73fcf_row1_col2" class="data row1 col2" >17.063855</td>
#                         <td id="T_73fcf_row1_col3" class="data row1 col3" >21.000000</td>
#                         <td id="T_73fcf_row1_col4" class="data row1 col4" >35.000000</td>
#                         <td id="T_73fcf_row1_col5" class="data row1 col5" >50.000000</td>
#                         <td id="T_73fcf_row1_col6" class="data row1 col6" >65.000000</td>
#                         <td id="T_73fcf_row1_col7" class="data row1 col7" >79.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_73fcf_level0_row2" class="row_heading level0 row2" >Experience</th>
#                         <td id="T_73fcf_row2_col0" class="data row2 col0" >252000.000000</td>
#                         <td id="T_73fcf_row2_col1" class="data row2 col1" >10.084437</td>
#                         <td id="T_73fcf_row2_col2" class="data row2 col2" >6.002590</td>
#                         <td id="T_73fcf_row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_73fcf_row2_col4" class="data row2 col4" >5.000000</td>
#                         <td id="T_73fcf_row2_col5" class="data row2 col5" >10.000000</td>
#                         <td id="T_73fcf_row2_col6" class="data row2 col6" >15.000000</td>
#                         <td id="T_73fcf_row2_col7" class="data row2 col7" >20.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_73fcf_level0_row3" class="row_heading level0 row3" >CURRENT_JOB_YRS</th>
#                         <td id="T_73fcf_row3_col0" class="data row3 col0" >252000.000000</td>
#                         <td id="T_73fcf_row3_col1" class="data row3 col1" >6.333877</td>
#                         <td id="T_73fcf_row3_col2" class="data row3 col2" >3.647053</td>
#                         <td id="T_73fcf_row3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_73fcf_row3_col4" class="data row3 col4" >3.000000</td>
#                         <td id="T_73fcf_row3_col5" class="data row3 col5" >6.000000</td>
#                         <td id="T_73fcf_row3_col6" class="data row3 col6" >9.000000</td>
#                         <td id="T_73fcf_row3_col7" class="data row3 col7" >14.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_73fcf_level0_row4" class="row_heading level0 row4" >CURRENT_HOUSE_YRS</th>
#                         <td id="T_73fcf_row4_col0" class="data row4 col0" >252000.000000</td>
#                         <td id="T_73fcf_row4_col1" class="data row4 col1" >11.997794</td>
#                         <td id="T_73fcf_row4_col2" class="data row4 col2" >1.399037</td>
#                         <td id="T_73fcf_row4_col3" class="data row4 col3" >10.000000</td>
#                         <td id="T_73fcf_row4_col4" class="data row4 col4" >11.000000</td>
#                         <td id="T_73fcf_row4_col5" class="data row4 col5" >12.000000</td>
#                         <td id="T_73fcf_row4_col6" class="data row4 col6" >13.000000</td>
#                         <td id="T_73fcf_row4_col7" class="data row4 col7" >14.000000</td>
#             </tr>
#     </tbody></table>

# %%
#Lets check the Target features first
fig = plt.figure(figsize=(10,6))
ax=sns.countplot(data=df_train, x='Risk_Flag')
for i in ax.patches:
    ax.text(x=i.get_x()+i.get_width()/2, y=i.get_height()/7, s=f"{np.round(i.get_height()/len(df_train)*100,0)}%", ha='center', size=40, weight='bold', rotation=360, color='white')
plt.title("Risk_Flag Feature", size=20, weight='bold')
plt.annotate(text="No potential default on loans", xytext=(0.5,150000),xy=(0.2,120000), arrowprops =dict(arrowstyle="->", color='black', connectionstyle="angle3,angleA=0,angleB=90"), color='black')
plt.annotate(text="Potential default on loans", xytext=(0.8,130000),xy=(1,30000), arrowprops =dict(arrowstyle="->", color='black',  connectionstyle="angle3,angleA=0,angleB=90"), color='black')
plt.show()

# %% [markdown]
# ###### The classes are heavily skewed we need to solve this issue later, with algorithm SMOTE (Synthetic Minority Oversampling TEchnique).
#
# ###### Class 0 represents 88.00% of the dataset, while class 1 only 12.00%.

# %%
g = sns.PairGrid(df_train)
g.map(sns.scatterplot)
plt.show()

# %% [markdown]
# # PREPROCESSING
#
# #### Management of binary categorical data

# %%
from sklearn.preprocessing import LabelEncoder

binary_class = ['Married/Single', 'Car_Ownership']
for column in binary_class:
    print ( '\nBefore:', df_train [column].unique () )
    lab_enc = LabelEncoder()
    df_train [column] = lab_enc.fit_transform ( df_train [column].values )
    print ('')
    print ( 'After:\n', df_train [column] )
    print ( '*' * 50 )

# rename column Single
df_train.rename(columns = { 'Married/Single' : 'Single' }, inplace = True)
df_train['Single']=df_train['Single'].astype('category')
df_train['Car_Ownership']=df_train['Car_Ownership'].astype('category')
# Out:
# Before: ['single' 'married']
#
# After:
#  0         1
# 1         1
# 2         0
# 3         1
# 4         1
#          ..
# 251995    1
# 251996    1
# 251997    1
# 251998    1
# 251999    1
# Name: Married/Single, Length: 252000, dtype: int64
# **************************************************
#
# Before: ['no' 'yes']
#
# After:
#  0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 251995    0
# 251996    0
# 251997    0
# 251998    0
# 251999    0
# Name: Car_Ownership, Length: 252000, dtype: int64
# **************************************************

# %% [markdown]
# #### Management of categorical data
#
# **One-Hot coding** for the other categorical columns, otherwise one of the most common mistakes would be made, i.e. the classification algorithm will assume that there is an order of magnitude between the various professions, states or cities.

# %%
one_hot_class = ['House_Ownership', 'CITY', 'STATE', 'Profession']
for column in one_hot_class:
    one_hot = pd.get_dummies ( df_train [column] ,
                drop_first = True)
    df_train = pd.concat([df_train, one_hot], axis=1)
    df_train.drop (column, axis = 1, inplace = True )
    
df_train.head().style.set_properties(**{'background-color':'black',
                                     'color': 'white'})
# Out:
# <style  type="text/css" >
# #T_02f15_row0_col0,#T_02f15_row0_col1,#T_02f15_row0_col2,#T_02f15_row0_col3,#T_02f15_row0_col4,#T_02f15_row0_col5,#T_02f15_row0_col6,#T_02f15_row0_col7,#T_02f15_row0_col8,#T_02f15_row0_col9,#T_02f15_row0_col10,#T_02f15_row0_col11,#T_02f15_row0_col12,#T_02f15_row0_col13,#T_02f15_row0_col14,#T_02f15_row0_col15,#T_02f15_row0_col16,#T_02f15_row0_col17,#T_02f15_row0_col18,#T_02f15_row0_col19,#T_02f15_row0_col20,#T_02f15_row0_col21,#T_02f15_row0_col22,#T_02f15_row0_col23,#T_02f15_row0_col24,#T_02f15_row0_col25,#T_02f15_row0_col26,#T_02f15_row0_col27,#T_02f15_row0_col28,#T_02f15_row0_col29,#T_02f15_row0_col30,#T_02f15_row0_col31,#T_02f15_row0_col32,#T_02f15_row0_col33,#T_02f15_row0_col34,#T_02f15_row0_col35,#T_02f15_row0_col36,#T_02f15_row0_col37,#T_02f15_row0_col38,#T_02f15_row0_col39,#T_02f15_row0_col40,#T_02f15_row0_col41,#T_02f15_row0_col42,#T_02f15_row0_col43,#T_02f15_row0_col44,#T_02f15_row0_col45,#T_02f15_row0_col46,#T_02f15_row0_col47,#T_02f15_row0_col48,#T_02f15_row0_col49,#T_02f15_row0_col50,#T_02f15_row0_col51,#T_02f15_row0_col52,#T_02f15_row0_col53,#T_02f15_row0_col54,#T_02f15_row0_col55,#T_02f15_row0_col56,#T_02f15_row0_col57,#T_02f15_row0_col58,#T_02f15_row0_col59,#T_02f15_row0_col60,#T_02f15_row0_col61,#T_02f15_row0_col62,#T_02f15_row0_col63,#T_02f15_row0_col64,#T_02f15_row0_col65,#T_02f15_row0_col66,#T_02f15_row0_col67,#T_02f15_row0_col68,#T_02f15_row0_col69,#T_02f15_row0_col70,#T_02f15_row0_col71,#T_02f15_row0_col72,#T_02f15_row0_col73,#T_02f15_row0_col74,#T_02f15_row0_col75,#T_02f15_row0_col76,#T_02f15_row0_col77,#T_02f15_row0_col78,#T_02f15_row0_col79,#T_02f15_row0_col80,#T_02f15_row0_col81,#T_02f15_row0_col82,#T_02f15_row0_col83,#T_02f15_row0_col84,#T_02f15_row0_col85,#T_02f15_row0_col86,#T_02f15_row0_col87,#T_02f15_row0_col88,#T_02f15_row0_col89,#T_02f15_row0_col90,#T_02f15_row0_col91,#T_02f15_row0_col92,#T_02f15_row0_col93,#T_02f15_row0_col94,#T_02f15_row0_col95,#T_02f15_row0_col96,#T_02f15_row0_col97,#T_02f15_row0_col98,#T_02f15_row0_col99,#T_02f15_row0_col100,#T_02f15_row0_col101,#T_02f15_row0_col102,#T_02f15_row0_col103,#T_02f15_row0_col104,#T_02f15_row0_col105,#T_02f15_row0_col106,#T_02f15_row0_col107,#T_02f15_row0_col108,#T_02f15_row0_col109,#T_02f15_row0_col110,#T_02f15_row0_col111,#T_02f15_row0_col112,#T_02f15_row0_col113,#T_02f15_row0_col114,#T_02f15_row0_col115,#T_02f15_row0_col116,#T_02f15_row0_col117,#T_02f15_row0_col118,#T_02f15_row0_col119,#T_02f15_row0_col120,#T_02f15_row0_col121,#T_02f15_row0_col122,#T_02f15_row0_col123,#T_02f15_row0_col124,#T_02f15_row0_col125,#T_02f15_row0_col126,#T_02f15_row0_col127,#T_02f15_row0_col128,#T_02f15_row0_col129,#T_02f15_row0_col130,#T_02f15_row0_col131,#T_02f15_row0_col132,#T_02f15_row0_col133,#T_02f15_row0_col134,#T_02f15_row0_col135,#T_02f15_row0_col136,#T_02f15_row0_col137,#T_02f15_row0_col138,#T_02f15_row0_col139,#T_02f15_row0_col140,#T_02f15_row0_col141,#T_02f15_row0_col142,#T_02f15_row0_col143,#T_02f15_row0_col144,#T_02f15_row0_col145,#T_02f15_row0_col146,#T_02f15_row0_col147,#T_02f15_row0_col148,#T_02f15_row0_col149,#T_02f15_row0_col150,#T_02f15_row0_col151,#T_02f15_row0_col152,#T_02f15_row0_col153,#T_02f15_row0_col154,#T_02f15_row0_col155,#T_02f15_row0_col156,#T_02f15_row0_col157,#T_02f15_row0_col158,#T_02f15_row0_col159,#T_02f15_row0_col160,#T_02f15_row0_col161,#T_02f15_row0_col162,#T_02f15_row0_col163,#T_02f15_row0_col164,#T_02f15_row0_col165,#T_02f15_row0_col166,#T_02f15_row0_col167,#T_02f15_row0_col168,#T_02f15_row0_col169,#T_02f15_row0_col170,#T_02f15_row0_col171,#T_02f15_row0_col172,#T_02f15_row0_col173,#T_02f15_row0_col174,#T_02f15_row0_col175,#T_02f15_row0_col176,#T_02f15_row0_col177,#T_02f15_row0_col178,#T_02f15_row0_col179,#T_02f15_row0_col180,#T_02f15_row0_col181,#T_02f15_row0_col182,#T_02f15_row0_col183,#T_02f15_row0_col184,#T_02f15_row0_col185,#T_02f15_row0_col186,#T_02f15_row0_col187,#T_02f15_row0_col188,#T_02f15_row0_col189,#T_02f15_row0_col190,#T_02f15_row0_col191,#T_02f15_row0_col192,#T_02f15_row0_col193,#T_02f15_row0_col194,#T_02f15_row0_c ...

# %%
print ( df_train.info() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Columns: 404 entries, Income to Web_designer
# dtypes: category(3), int64(5), uint8(396)
# memory usage: 105.5 MB
# None

# %% [markdown]
# #### Train and test split

# %%
from sklearn.model_selection import train_test_split
X, y = df_train.drop ('Risk_Flag', axis=1).values , df_train.Risk_Flag.values
X_train, X_test, y_train, y_test = train_test_split ( X, y,
                                                     test_size = 0.3,
                                                     random_state = 1,
                                                     stratify = y)

# %% [markdown]
# #### Minority class oversampling in the training dataset (SMOTE)

# %%
from imblearn.over_sampling import SMOTE

print ('Number of observations in the target variable before oversampling of the minority class:', np.bincount (y_train) )

smt = SMOTE ()
X_train, y_train = smt.fit_resample (X_train, y_train)

print ('\nNumber of observations in the target variable after oversampling of the minority class:', np.bincount (y_train) )
# Out:
# Number of observations in the target variable before oversampling of the minority class: [154703  21697]
#
# Number of observations in the target variable after oversampling of the minority class: [154703 154703]

# %% [markdown]
# #### Standardization of variables

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
X_train_std = std_scaler.fit_transform ( X_train )
X_test_std = std_scaler.transform ( X_test )

# %% [markdown]
# # MODEL SELECTION AND EVALUATION OF PERFORMANCE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

tree = DecisionTreeClassifier ( random_state = 1 )
tree.fit ( X_train_std, y_train )
y_pred = tree.predict ( X_test_std )
print ( 'Accuracy score: %.2f' %accuracy_score ( y_test, y_pred ) )
print ( 'Roc_Auc score: %.2f' %roc_auc_score ( y_test, y_pred ) )
# Out:
# Accuracy score: 0.87
# Roc_Auc score: 0.86

# %% [markdown]
# #### HYPERPARAMETERS OPTIMIZATION

# %%
from sklearn.model_selection import GridSearchCV
# range of parameter values
split_range = [ 8, 10 ]
# parameters grid
grid_param = [
    { 'criterion' : [ 'entropy' ],
     'splitter' : [ 'best', 'random' ],
     'min_samples_split' : split_range }
]
gs = GridSearchCV ( estimator = tree,
                   param_grid = grid_param,
                   scoring = 'roc_auc',
                   cv = 3,
                   refit = True,
                   n_jobs = 4
                   )

gs = gs.fit ( X_train, y_train )

print ( 'Best hyperparameter:', gs.best_params_ )

print ( 'Best score: %.3f' %gs.best_score_ )

gs = gs.best_estimator_
# Out:
# Best hyperparameter: {'criterion': 'entropy', 'min_samples_split': 10, 'splitter': 'random'}
# Best score: 0.941

# %%
gs.fit ( X_train_std, y_train )
y_pred_gs = gs.predict ( X_test_std )
print ( 'Accuracy score: %.2f' %accuracy_score ( y_test, y_pred_gs ) )
print ( 'Roc_Auc score: %.2f' %roc_auc_score ( y_test, y_pred_gs ) )
# Out:
# Accuracy score: 0.88
# Roc_Auc score: 0.85

# %% [markdown]
# Following model optimization:
#
# - accuracy has improved (0,87 --> 0,88)
#
# - the rac_auc score is fixed at 0.85.
#
# Now let's see in detail what errors the model makes on the test data through the confusion matrix.

# %% [markdown]
# #### CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix (  y_test, y_pred_gs )

fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
#plot 1
sns.heatmap(conf_matrix,ax=axes[0],annot=True, cmap='Blues', cbar=False, fmt='d')
axes[0].set_xlabel('\nPredicted label', size = 14)
axes[0].set_ylabel('True label\n', size = 14)

# plot 2
sns.heatmap(conf_matrix/np.sum(conf_matrix),ax=axes[1], annot=True, 
            fmt='.2%', cmap='Blues', cbar=False)
axes[1].set_xlabel('\nPredicted label', size = 14)
axes[1].set_ylabel('True label\n', size = 14)
axes[1].yaxis.tick_left()
plt.show()

# %% [markdown]
# From the confusion matrices it can be deduced that:
#
# - the model fails 2.30% of the time to classify it as non-potential default
#
# - in general, it is noted that it is more wrong to classify as potential defaulting those who in reality are not (9.88%)

# %% [markdown]
# # CONCLUSIONS AND FINAL CONSIDERATIONS

# %% [markdown]
# **Based on the requirements of the task in question, we can conclude that the trained tree model achieved a good roc_auc_score of 0.85.**
#
# **For a more in-depth analysis it is advisable to test other classification algortms, perhaps more performing, or to test some ensemble algorithm.**
#
# **I await comments and / or suggestions.**
